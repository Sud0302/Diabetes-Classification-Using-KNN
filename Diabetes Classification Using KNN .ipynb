# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# ### Import the data sets

# %%
x_train = pd.read_csv(r'C:\Users\sudha\Documents\AI-Mafia-Machine--Learning-bf031ed01d9bd5d1da3485f6415254195ac38284\Week 3 - KNN Assignment\Training Data\Diabetes_XTrain.csv')
y_train = pd.read_csv(r'C:\Users\sudha\Documents\AI-Mafia-Machine--Learning-bf031ed01d9bd5d1da3485f6415254195ac38284\Week 3 - KNN Assignment\Training Data\Diabetes_YTrain.csv')

x_test = pd.read_csv(r'C:\Users\sudha\Documents\AI-Mafia-Machine--Learning-bf031ed01d9bd5d1da3485f6415254195ac38284\Week 3 - KNN Assignment\Testing Data\Diabetes_XTest.csv')

               

# Convert the imported data to numpy arrays 
                      
x = x_train.values
y = y_train.values
x_t = x_test.values

# Now the first column is just serial no so we need to remove it

x = x[:,1:]
y = y[:,0]
x_t = x_t[:,1:]

print(x_train.describe())
print (x_train)
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   576.000000  576.000000     576.000000     576.000000  576.000000
# mean      3.758681  119.975694      68.826389      20.364583   76.166667
# std       3.328783   31.512914      20.285812      15.893856  109.193550
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  116.000000      72.000000      22.000000   36.000000
# 75%       6.000000  139.000000      80.000000      32.000000  120.000000
# max      17.000000  199.000000     122.000000      63.000000  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  576.000000                576.000000  576.000000
# mean    31.857292                  0.481519   32.954861
# std      8.134926                  0.336910   11.878137
# min      0.000000                  0.078000   21.000000
# ...

# %% [markdown]
# ### Visualising the training Data

# %%
plt.bar(x_train['Pregnancies'].value_counts().index , x_train['Pregnancies'].value_counts())
plt.xlabel('No of Pregnancies', fontweight='bold', color = 'orange', fontsize='10', horizontalalignment='center')
plt.ylabel('No of individuals with Diabetes', fontweight='bold', color = 'orange', fontsize='10', verticalalignment='center')
plt.title('No of individuals with diabetes with respect to the No of Pregnencies')
# Out:
# Text(0.5, 1.0, 'No of individuals with diabetes with respect to the No of Pregnencies')

# %%
plt.bar(x_train['Glucose'].value_counts().index , x_train['Glucose'].value_counts())
plt.xlabel('Glucose Level', fontweight='bold', color = 'orange', fontsize='10', horizontalalignment='center')
plt.ylabel('No of individuals with Diabetes', fontweight='bold', color = 'orange', fontsize='10', verticalalignment='center')
plt.title('No of individuals with diabetes with respect to the Glucose Level')
# Out:
# Text(0.5, 1.0, 'No of individuals with diabetes with respect to the Glucose Level')

# %%
plt.bar(x_train['BloodPressure'].value_counts().index , x_train['BloodPressure'].value_counts())
plt.xlabel('BloodPressure Level', fontweight='bold', color = 'orange', fontsize='10', horizontalalignment='center')
plt.ylabel('No of individuals with Diabetes', fontweight='bold', color = 'orange', fontsize='10', verticalalignment='center')
plt.title('No of individuals with diabetes with respect to the BloodPressure Level')
# Out:
# Text(0.5, 1.0, 'No of individuals with diabetes with respect to the BloodPressure Level')

# %%
plt.bar(x_train['SkinThickness'].value_counts().index , x_train['SkinThickness'].value_counts())
plt.xlabel('Thickness of the skin', fontweight='bold', color = 'orange', fontsize='10', horizontalalignment='center')
plt.ylabel('No of individuals with Diabetes', fontweight='bold', color = 'orange', fontsize='10', verticalalignment='center')
plt.title('No of individuals with diabetes with respect to their Skin Thickness')
# Out:
# Text(0.5, 1.0, 'No of individuals with diabetes with respect to their Skin Thickness')

# %%
plt.bar(x_train['Insulin'].value_counts().index , x_train['Insulin'].value_counts())
plt.xlabel('Insulin Level', fontweight='bold', color = 'orange', fontsize='10', horizontalalignment='center')
plt.ylabel('No of individuals with Diabetes', fontweight='bold', color = 'orange', fontsize='10', verticalalignment='center')
plt.title('No of individuals with diabetes with respect to their Insulin Level')
ymin, ymax = plt.ylim()
scale_factor = 0.05
plt.ylim(ymin * scale_factor, ymax * scale_factor)
# Out:
# (0.0, 14.594999999999999)

# %%
plt.bar(x_train['BMI'].value_counts().index , x_train['BMI'].value_counts())
plt.xlabel('BMI', fontweight='bold', color = 'orange', fontsize='10', horizontalalignment='center')
plt.ylabel('No of individuals with Diabetes', fontweight='bold', color = 'orange', fontsize='10', verticalalignment='center')
plt.title('No of individuals with diabetes with respect to the BMI')
# Out:
# Text(0.5, 1.0, 'No of individuals with diabetes with respect to the BMI')

# %%
plt.bar(x_train['DiabetesPedigreeFunction'].value_counts().index , x_train['DiabetesPedigreeFunction'].value_counts(),label = 'DPF')
plt.xlabel('DiabetesPedigreeFunction', fontweight='bold', color = 'orange', fontsize='10', horizontalalignment='center')
plt.ylabel('No of individuals with Diabetes', fontweight='bold', color = 'orange', fontsize='10', verticalalignment='center')
plt.title('No of individuals with diabetes with respect to the DiabetesPedigreeFunction')
# Out:
# Text(0.5, 1.0, 'No of individuals with diabetes with respect to the DiabetesPedigreeFunction')

# %%
plt.bar(x_train['Age'].value_counts().index , x_train['Age'].value_counts())
plt.xlabel('Age', fontweight='bold', color = 'orange', fontsize='10', horizontalalignment='center')
plt.ylabel('No of individuals with Diabetes', fontweight='bold', color = 'orange', fontsize='10', verticalalignment='center')
plt.title('No of individuals with diabetes with respect to the Age')
# Out:
# Text(0.5, 1.0, 'No of individuals with diabetes with respect to the Age')

# %%
plt.bar(x_train['Pregnancies'].value_counts().index , x_train['Pregnancies'].value_counts())
plt.bar(x_train['Glucose'].value_counts().index , x_train['Glucose'].value_counts())
plt.bar(x_train['BloodPressure'].value_counts().index , x_train['BloodPressure'].value_counts())
plt.bar(x_train['SkinThickness'].value_counts().index , x_train['SkinThickness'].value_counts())
plt.bar(x_train['Insulin'].value_counts().index , x_train['Insulin'].value_counts())
plt.bar(x_train['BMI'].value_counts().index , x_train['BMI'].value_counts())
plt.bar(x_train['DiabetesPedigreeFunction'].value_counts().index , x_train['DiabetesPedigreeFunction'].value_counts())
plt.bar(x_train['Age'].value_counts().index , x_train['Age'].value_counts())
ymin, ymax = plt.ylim()
scale_factor = 0.1
plt.ylim(ymin * scale_factor, ymax * scale_factor)
plt.legend
plt.show()

# %% [markdown]
# ### Prediction using KNN Algorithm

# %%
def dist(x1,x2):
    return np.sqrt(sum((x1-x2)**2))

def knn(X,Y,queryPoint,k=5):
    
    vals = []
    m = X.shape[0]
    
    for i in range(m):
        d = dist(queryPoint,X[i])
        vals.append((d,Y[i]))
        
    
    vals = sorted(vals)
    # Nearest/First K points
    vals = vals[:k]
    
    vals = np.array(vals)
    
    #print(vals)
    
    new_vals = np.unique(vals[:,1],return_counts=True)
    #print(new_vals)
    
    index = new_vals[1].argmax()
    pred = new_vals[0][index]
    
    return pred

# %%
pred_val =[]

for i in range(x_t.shape[0]):
    temp = knn(x,y,x_t[i])
    pred_val.append(temp)
    
# Exporting the results as a CSV file    

pred_val = np.array(pred_val)

np.savetxt('Diabetes_prediction.csv', [pred_val], delimiter=',', fmt='%d')
